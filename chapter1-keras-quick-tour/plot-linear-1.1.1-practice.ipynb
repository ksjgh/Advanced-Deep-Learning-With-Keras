# %%
'''Utility for plotting a linear function
with and without noise
'''

import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
want_noise = True

# %%
print(plt.style.available)
# Out:
# ['bmh', 'seaborn-white', 'seaborn-ticks', 'seaborn-poster', 'seaborn-bright', 'dark_background', 'seaborn-colorblind', 'tableau-colorblind10', 'fast', 'seaborn-pastel', 'grayscale', 'seaborn-deep', 'seaborn-talk', 'seaborn-notebook', 'ggplot', 'seaborn', 'seaborn-paper', 'seaborn-darkgrid', 'fivethirtyeight', '_classic_test', 'seaborn-dark-palette', 'seaborn-dark', 'seaborn-whitegrid', 'classic', 'Solarize_Light2', 'seaborn-muted']

# %%
# grayscale plot, comment if color is wanted
# plt.style.use('grayscale')
plt.style.use('ggplot')

# %%
# generate data bet -1,1 interval of 0.2
x = np.arange(-1,1,0.2)
y = 2*x + 3
plt.xlabel('x')
plt.ylabel('y=f(x)')
plt.plot(x, y, 'o-', label="y")
# plt.show()


if want_noise:
    # generate data with uniform distribution
    noise = np.random.uniform(-0.2, 0.2, x.shape)
    xn = x + noise

    plt.ylabel('y=f(x)')
    plt.plot(xn, y, 's-', label="y with noised x")

plt.legend(loc=0)
plt.grid(b=True)
# plt.savefig("linear_regression.png")
plt.show()
# plt.close('all')
